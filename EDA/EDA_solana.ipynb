# %% [markdown]
# # EDA solana

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
solana_df = pd.read_csv("../Dataframes/solana_df.csv")
solana_df["date"] = pd.to_datetime(solana_df["date"])

# %%
solana_df.columns
# Out:
# Index(['date', 'id', 'prices', 'price_diff', 'returns', 'market_caps',
#        'market_caps_diff', 'total_volumes', 'total_volumes_diff', 'open',
#        'high', 'low'],
#       dtype='object')

# %%
solana_df.head()
# Out:
#         date      id  prices  price_diff  returns  market_caps  \
# 0 2020-04-11  solana    0.96         NaN      NaN   7827651.89
# 1 2020-04-15  solana    0.67       -0.12  -0.0012   5306221.07
# 2 2020-04-19  solana    0.68        0.02   0.0002   5423066.29
# 3 2020-04-23  solana    0.68        0.11   0.0011   5446538.17
# 4 2020-04-27  solana    0.64       -0.01  -0.0001   5137791.33
#
#    market_caps_diff  total_volumes  total_volumes_diff  open  high   low
# 0               NaN    92672667.43                 NaN  0.96  0.96  0.96
# 1        -996143.08    17523533.05         -2055681.84  0.78  0.88  0.67
# 2          74742.31    10199318.16           -27716.59  0.64  0.69  0.64
# 3         854991.41    18146790.14          8535948.15  0.61  0.68  0.53
# 4         -35827.90     8493459.05          1168497.78  0.62  0.65  0.62

# %%
solana_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320 entries, 0 to 319
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                320 non-null    datetime64[ns]
#  1   id                  320 non-null    object
#  2   prices              320 non-null    float64
#  3   price_diff          319 non-null    float64
#  4   returns             319 non-null    float64
#  5   market_caps         320 non-null    float64
#  6   market_caps_diff    319 non-null    float64
#  7   total_volumes       320 non-null    float64
#  8   total_volumes_diff  319 non-null    float64
#  9   open                320 non-null    float64
#  10  high                320 non-null    float64
#  11  low                 320 non-null    float64
# dtypes: datetime64[ns](1), float64(10), object(1)
# memory usage: 30.1+ KB

# %%
solana_df.describe().astype(str)
# Out:
#                       date             prices            price_diff  \
# count                  320              320.0                 319.0
# mean   2021-12-14 00:40:30         45.3134375  0.023761755485893054
# min    2020-04-11 00:00:00               0.54                -24.03
# 25%    2021-02-10 00:00:00             8.0775   -0.7950000000000017
# 50%    2021-12-13 00:00:00              24.41   -0.0099999999999997
# 75%    2022-10-16 00:00:00              43.71    0.6799999999999997
# max    2023-08-19 00:00:00             259.24     25.64000000000001
# std                    nan  56.03877156535532     4.721851080730486
#
#                       returns         market_caps     market_caps_diff  \
# count                   319.0               320.0                319.0
# mean    0.0002376175548589306  14264252997.884064   -7092178.503416916
# min                   -0.2403          4324416.95   -6999265687.030006
# ...

# %%
fig = px.line(solana_df, x="date", y="prices", color="id",
              title="Precio de la moneda")

fig.show()

# %%
fig_price_returns = px.line(solana_df, x='date', y='price_diff', title='comparacion de precio en el tiempo de acuredo al dia anterior')
fig_price_returns.show()

# %% [markdown]
# Este comportamiento nos muestra que tanto cambia el precio de la moneda

# %%
fig = px.line(solana_df, x="date", y="market_caps", color="id",
              title="Capitalizacion del mercado de la moneda")

fig.show()

# %% [markdown]
# se puede obserbar que las lineas son muy similares solo que el precio esta en miles y la capitalizacion del mercado esta en miles de millones

# %%
fig_price_returns = px.line(solana_df, x='date', y='market_caps_diff', title='comparacion del la capitalizacion de mercado en el tiempo de acuredo al dia anterior')
fig_price_returns.show()

# %%
fig = px.line(solana_df, x="date", y="total_volumes", color="id",
              title="Volumen de la moneda")

fig.show()

# %%
fig_price_returns = px.line(solana_df, x='date', y='total_volumes_diff', title='comparacion de volumen en el tiempo de acuredo al dia anterior')
fig_price_returns.show()

# %%
# Crear un gráfico de barras de las diferencias de precios en diferentes fechas
fig_price_returns = px.scatter(solana_df, x='prices', y='returns', title='Relación entre Precios y Retornos de la moneda')
fig_price_returns.show()

# %%
volatility = solana_df["returns"].std()
print(f"Volatilidad: {volatility:.2%}")
# Out:
# Volatilidad: 4.72%
