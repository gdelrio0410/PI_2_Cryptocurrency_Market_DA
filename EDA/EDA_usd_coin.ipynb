# %% [markdown]
# # EDA usd-coin

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
usd_coin_df = pd.read_csv("../Dataframes/usd_coin_df.csv")
usd_coin_df["date"] = pd.to_datetime(usd_coin_df["date"])

# %%
usd_coin_df.columns
# Out:
# Index(['date', 'id', 'prices', 'price_diff', 'returns', 'market_caps',
#        'market_caps_diff', 'total_volumes', 'total_volumes_diff', 'open',
#        'high', 'low'],
#       dtype='object')

# %%
usd_coin_df.head()
# Out:
#         date        id  prices  price_diff  returns  market_caps  \
# 0 2018-10-07  usd-coin    1.00        0.00   0.0000          0.0
# 1 2018-10-11  usd-coin    1.00        0.00   0.0000          0.0
# 2 2018-10-15  usd-coin    1.02        0.01   0.0001          0.0
# 3 2018-10-19  usd-coin    1.02       -0.01  -0.0001          0.0
# 4 2018-10-23  usd-coin    1.02       -0.01  -0.0001          0.0
#
#    market_caps_diff  total_volumes  total_volumes_diff  open  high   low
# 0              0.00       49324.69            29069.98  1.01  1.01  1.00
# 1              0.00       48789.48             6976.98  1.00  1.00  1.00
# 2              0.00      114047.47           -19758.91  1.01  1.02  1.01
# 3      -24590235.09      577029.87         -1242982.36  1.04  1.04  1.02
# 4              0.00      475698.12           264447.40  1.02  1.03  1.02

# %%
usd_coin_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 464 entries, 0 to 463
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                464 non-null    datetime64[ns]
#  1   id                  464 non-null    object
#  2   prices              464 non-null    float64
#  3   price_diff          464 non-null    float64
#  4   returns             464 non-null    float64
#  5   market_caps         464 non-null    float64
#  6   market_caps_diff    464 non-null    float64
#  7   total_volumes       464 non-null    float64
#  8   total_volumes_diff  464 non-null    float64
#  9   open                464 non-null    float64
#  10  high                464 non-null    float64
#  11  low                 464 non-null    float64
# dtypes: datetime64[ns](1), float64(10), object(1)
# memory usage: 43.6+ KB

# %%
usd_coin_df.describe().astype(str)
# Out:
#                                 date                prices  \
# count                            464                 464.0
# mean   2021-03-13 04:20:41.379310336    1.0010991379310346
# min              2018-10-07 00:00:00                  0.99
# 25%              2019-12-26 00:00:00                   1.0
# 50%              2021-03-13 00:00:00                   1.0
# 75%              2022-05-31 18:00:00                   1.0
# max              2023-08-19 00:00:00                  1.04
# std                              nan  0.004725611404138273
#
#                    price_diff                 returns         market_caps  \
# count                   464.0                   464.0               464.0
# mean   0.00017241379310344832  1.7241379310344831e-06   19550983905.34127
# min                     -0.02                 -0.0002                 0.0
# 25%                       0.0                     0.0       459040224.645
# ...

# %%
fig = px.line(usd_coin_df, x="date", y="prices", color="id",
              title="Precio de la moneda")

fig.show()

# %%
fig_price_returns = px.line(usd_coin_df, x='date', y='price_diff', title='comparacion de precio en el tiempo de acuredo al dia anterior')
fig_price_returns.show()

# %% [markdown]
# Este comportamiento nos muestra que tanto cambia el precio de la moneda

# %%
fig = px.line(usd_coin_df, x="date", y="market_caps", color="id",
              title="Capitalizacion del mercado de la moneda")

fig.show()

# %% [markdown]
# se puede obserbar que las lineas son muy similares solo que el precio esta en miles y la capitalizacion del mercado esta en miles de millones

# %%
fig_price_returns = px.line(usd_coin_df, x='date', y='market_caps_diff', title='comparacion del la capitalizacion de mercado en el tiempo de acuredo al dia anterior')
fig_price_returns.show()

# %%
fig = px.line(usd_coin_df, x="date", y="total_volumes", color="id",
              title="Volumen de la moneda")

fig.show()

# %%
fig_price_returns = px.line(usd_coin_df, x='date', y='total_volumes_diff', title='comparacion de volumen en el tiempo de acuredo al dia anterior')
fig_price_returns.show()

# %%
# Crear un gráfico de barras de las diferencias de precios en diferentes fechas
fig_price_returns = px.scatter(usd_coin_df, x='prices', y='returns', title='Relación entre Precios y Retornos de la moneda')
fig_price_returns.show()

# %%
volatility = usd_coin_df["returns"].std()
print(f"Volatilidad: {volatility:.2%}")
# Out:
# Volatilidad: 0.00%
