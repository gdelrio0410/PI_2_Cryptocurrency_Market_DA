# %% [markdown]
# # EDA staked-ether

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
staked_ether_df = pd.read_csv("../Dataframes/staked_ether_df.csv")
staked_ether_df["date"] = pd.to_datetime(staked_ether_df["date"])

# %%
staked_ether_df.columns
# Out:
# Index(['date', 'id', 'prices', 'price_diff', 'returns', 'market_caps',
#        'market_caps_diff', 'total_volumes', 'total_volumes_diff', 'open',
#        'high', 'low'],
#       dtype='object')

# %%
staked_ether_df.head()
# Out:
#         date            id   prices  price_diff  returns  market_caps  \
# 0 2020-12-23  staked-ether   617.16        0.00   0.0000         0.00
# 1 2020-12-27  staked-ether   629.07        4.27   0.0427   7530256.10
# 2 2020-12-31  staked-ether   722.28       -0.49  -0.0049  11905413.95
# 3 2021-01-03  staked-ether   772.06       48.53   0.4853  13205950.41
# 4 2021-01-07  staked-ether  1173.33       59.43   0.5943  21396653.60
#
#    market_caps_diff  total_volumes  total_volumes_diff    open     high  \
# 0              0.00      137563.03                0.00  617.16   617.16
# 1         245512.15       10300.37           -35632.69  596.77   629.07
# 2         412037.55       95848.21           -20893.23  678.10   730.42
# 3        1082507.63       34572.92            29468.27  733.32   772.06
# 4        2014800.85       38065.92          -404512.05  977.57  1173.33
#
#       low
# 0  617.16
# 1  596.77
# 2  678.10
# 3  723.53
# 4  966.90

# %%
staked_ether_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                253 non-null    datetime64[ns]
#  1   id                  253 non-null    object
#  2   prices              253 non-null    float64
#  3   price_diff          253 non-null    float64
#  4   returns             253 non-null    float64
#  5   market_caps         253 non-null    float64
#  6   market_caps_diff    253 non-null    float64
#  7   total_volumes       253 non-null    float64
#  8   total_volumes_diff  253 non-null    float64
#  9   open                253 non-null    float64
#  10  high                253 non-null    float64
#  11  low                 253 non-null    float64
# dtypes: datetime64[ns](1), float64(10), object(1)
# memory usage: 23.8+ KB

# %%
staked_ether_df.describe().astype(str)
# Out:
#                                 date              prices           price_diff  \
# count                            253               253.0                253.0
# mean   2022-04-21 17:32:57.865612544  2194.3634387351776  -0.7361660079051442
# min              2020-12-23 00:00:00              617.16   -475.1200000000004
# 25%              2021-08-23 00:00:00             1564.71   -39.99000000000001
# 50%              2022-04-23 00:00:00             1867.56    2.009999999999991
# 75%              2022-12-19 00:00:00             2828.21    48.52999999999997
# max              2023-08-19 00:00:00             4598.41    378.5899999999997
# std                              nan   914.6408589343555    93.26265784512793
#
#                      returns        market_caps    market_caps_diff  \
# count                  253.0              253.0               253.0
# mean   -0.007361660079051449  6106510423.576204  1957324.3835968603
# ...

# %%
fig = px.line(staked_ether_df, x="date", y="prices", color="id",
              title="Precio de la moneda")

fig.show()

# %%
fig_price_returns = px.line(staked_ether_df, x='date', y='price_diff', title='comparacion de precio en el tiempo de acuredo al dia anterior')
fig_price_returns.show()

# %% [markdown]
# Este comportamiento nos muestra que tanto cambia el precio de la moneda

# %%
fig = px.line(staked_ether_df, x="date", y="market_caps", color="id",
              title="Capitalizacion del mercado de la moneda")

fig.show()

# %% [markdown]
# se puede obserbar que las lineas son muy similares solo que el precio esta en miles y la capitalizacion del mercado esta en miles de millones

# %%
fig_price_returns = px.line(staked_ether_df, x='date', y='market_caps_diff', title='comparacion del la capitalizacion de mercado en el tiempo de acuredo al dia anterior')
fig_price_returns.show()

# %%
fig = px.line(staked_ether_df, x="date", y="total_volumes", color="id",
              title="Volumen de la moneda")

fig.show()

# %%
fig_price_returns = px.line(staked_ether_df, x='date', y='total_volumes_diff', title='comparacion de volumen en el tiempo de acuredo al dia anterior')
fig_price_returns.show()

# %%
# Crear un gráfico de barras de las diferencias de precios en diferentes fechas
fig_price_returns = px.scatter(staked_ether_df, x='prices', y='returns', title='Relación entre Precios y Retornos de la moneda')
fig_price_returns.show()

# %%
volatility = staked_ether_df["returns"].std()
print(f"Volatilidad: {volatility:.2%}")
# Out:
# Volatilidad: 93.26%
