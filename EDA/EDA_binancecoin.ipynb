# %% [markdown]
# # EDA de binance coin

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
binancecoin_df = pd.read_csv("../Dataframes/binancecoin_df.csv")
binancecoin_df["date"] = pd.to_datetime(binancecoin_df["date"])

# %%
binancecoin_df.columns
# Out:
# Index(['date', 'id', 'prices', 'price_diff', 'returns', 'market_caps',
#        'market_caps_diff', 'total_volumes', 'total_volumes_diff', 'open',
#        'high', 'low'],
#       dtype='object')

# %%
binancecoin_df.head()
# Out:
#         date           id  prices  price_diff  returns  market_caps  \
# 0 2017-09-19  binancecoin    0.17        0.00   0.0000  16833419.06
# 1 2017-09-23  binancecoin    0.09        0.00   0.0000   8828963.16
# 2 2017-09-27  binancecoin    0.12        0.03   0.0003  11505513.15
# 3 2017-09-30  binancecoin    0.17        0.04   0.0004  17191164.68
# 4 2017-10-03  binancecoin    0.12        0.01   0.0001  12443238.40
#
#    market_caps_diff  total_volumes  total_volumes_diff  open  high   low
# 0        -515704.85           3.88               -2.12  0.11  0.17  0.11
# 1        -592334.93           0.79             -135.09  0.17  0.17  0.09
# 2        2539732.93          59.55               41.36  0.09  0.12  0.09
# 3        3973835.89         204.64              202.02  0.14  0.17  0.13
# 4        1655874.35          42.09               27.65  0.10  0.12  0.10

# %%
binancecoin_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 564 entries, 0 to 563
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                564 non-null    datetime64[ns]
#  1   id                  564 non-null    object
#  2   prices              564 non-null    float64
#  3   price_diff          564 non-null    float64
#  4   returns             564 non-null    float64
#  5   market_caps         564 non-null    float64
#  6   market_caps_diff    564 non-null    float64
#  7   total_volumes       564 non-null    float64
#  8   total_volumes_diff  564 non-null    float64
#  9   open                564 non-null    float64
#  10  high                564 non-null    float64
#  11  low                 564 non-null    float64
# dtypes: datetime64[ns](1), float64(10), object(1)
# memory usage: 53.0+ KB

# %%
binancecoin_df.describe().astype(str)
# Out:
#                                 date              prices           price_diff  \
# count                            564               564.0                564.0
# mean   2020-09-02 10:28:05.106383104  157.76301418439718  -0.1463475177304964
# min              2017-09-19 00:00:00                0.04   -52.59999999999991
# 25%              2019-03-14 00:00:00  14.524999999999999  -0.8624999999999998
# 50%              2020-09-01 12:00:00              28.945   0.0350000000000143
# 75%              2022-02-24 00:00:00            304.6425   0.9224999999999985
# max              2023-08-19 00:00:00              654.63                40.94
# std                              nan  177.66266744704043     9.04063197030682
#
#                       returns        market_caps     market_caps_diff  \
# count                   564.0              564.0                564.0
# mean   -0.0014634751773049681  25148032563.48493   -45175138.54072702
# ...

# %%
fig = px.line(binancecoin_df, x="date", y="prices", color="id",
              title="Precio de la moneda")

fig.show()

# %%
fig_price_returns = px.line(binancecoin_df, x='date', y='price_diff', title='comparacion de precio en el tiempo de acuredo al dia anterior')
fig_price_returns.show()

# %% [markdown]
# Este comportamiento nos muestra que tanto cambia el precio de la moneda

# %%
fig = px.line(binancecoin_df, x="date", y="market_caps", color="id",
              title="Capitalizacion del mercado de la moneda")

fig.show()

# %% [markdown]
# se puede obserbar que las lineas son muy similares solo que el precio esta en miles y la capitalizacion del mercado esta en miles de millones

# %%
fig_price_returns = px.line(binancecoin_df, x='date', y='market_caps_diff', title='comparacion del la capitalizacion de mercado en el tiempo de acuredo al dia anterior')
fig_price_returns.show()

# %%
fig = px.line(binancecoin_df, x="date", y="total_volumes", color="id",
              title="Volumen de la moneda")

fig.show()

# %%
fig_price_returns = px.line(binancecoin_df, x='date', y='total_volumes_diff', title='comparacion de volumen en el tiempo de acuredo al dia anterior')
fig_price_returns.show()

# %%
# Crear un gráfico de barras de las diferencias de precios en diferentes fechas
fig_price_returns = px.scatter(binancecoin_df, x='prices', y='returns', title='Relación entre Precios y Retornos de la moneda')
fig_price_returns.show()

# %%
volatility = binancecoin_df["returns"].std()
print(f"Volatilidad: {volatility:.2%}")
# Out:
# Volatilidad: 9.04%
