# %% [markdown]
# # EDA cardano

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
cardano_df = pd.read_csv("../Dataframes/cardano_df.csv")
cardano_df["date"] = pd.to_datetime(cardano_df["date"])

# %%
cardano_df.columns
# Out:
# Index(['date', 'id', 'prices', 'price_diff', 'returns', 'market_caps',
#        'market_caps_diff', 'total_volumes', 'total_volumes_diff', 'open',
#        'high', 'low'],
#       dtype='object')

# %%
cardano_df.head()
# Out:
#         date       id  prices  price_diff  returns   market_caps  \
# 0 2017-10-19  cardano    0.03         0.0      0.0  6.956220e+08
# 1 2017-10-23  cardano    0.03         0.0      0.0  6.752738e+08
# 2 2017-10-27  cardano    0.03         0.0      0.0  6.873168e+08
# 3 2017-10-31  cardano    0.03         0.0      0.0  7.843223e+08
# 4 2017-11-03  cardano    0.02         0.0      0.0  5.908631e+08
#
#    market_caps_diff  total_volumes  total_volumes_diff  open  high   low
# 0        -399386.05     2815155.97           463477.85  0.03  0.03  0.03
# 1      -45396032.42     3505126.54           603250.42  0.03  0.03  0.03
# 2       -2120287.31     2569633.78           200233.54  0.03  0.03  0.03
# 3       48371819.16     7251416.95          3456663.93  0.03  0.03  0.03
# 4       38082937.23     3029089.74         -2926161.61  0.02  0.02  0.02

# %%
cardano_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 556 entries, 0 to 555
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                556 non-null    datetime64[ns]
#  1   id                  556 non-null    object
#  2   prices              556 non-null    float64
#  3   price_diff          556 non-null    float64
#  4   returns             556 non-null    float64
#  5   market_caps         556 non-null    float64
#  6   market_caps_diff    556 non-null    float64
#  7   total_volumes       556 non-null    float64
#  8   total_volumes_diff  556 non-null    float64
#  9   open                556 non-null    float64
#  10  high                556 non-null    float64
#  11  low                 556 non-null    float64
# dtypes: datetime64[ns](1), float64(10), object(1)
# memory usage: 52.2+ KB

# %%
cardano_df.describe().astype(str)
# Out:
#                                 date              prices  \
# count                            556               556.0
# mean   2020-09-17 18:46:37.122301952  0.4691726618705036
# min              2017-10-19 00:00:00                0.02
# 25%              2019-04-06 00:00:00                0.07
# 50%              2020-09-17 00:00:00               0.245
# 75%              2022-03-01 18:00:00                0.51
# max              2023-08-19 00:00:00                2.96
# std                              nan   0.589687380033013
#
#                   price_diff                 returns         market_caps  \
# count                  556.0                   556.0               556.0
# mean   0.0009352517985611511   9.352517985612957e-06  15016689192.480793
# min      -0.1799999999999997     -0.0017999999999999        577877214.21
# 25%      -0.0099999999999999  -9.999999999999996e-05     2234332948.4425
# 50%                      0.0                     0.0       6517742587.33
# ...

# %%
fig = px.line(cardano_df, x="date", y="prices", color="id",
              title="Precio de la moneda")

fig.show()

# %%
fig_price_returns = px.line(cardano_df, x='date', y='price_diff', title='comparacion de precio en el tiempo de acuredo al dia anterior')
fig_price_returns.show()

# %% [markdown]
# Este comportamiento nos muestra que tanto cambia el precio de la moneda

# %%
fig = px.line(cardano_df, x="date", y="market_caps", color="id",
              title="Capitalizacion del mercado de la moneda")

fig.show()

# %% [markdown]
# se puede obserbar que las lineas son muy similares solo que el precio esta en miles y la capitalizacion del mercado esta en miles de millones

# %%
fig_price_returns = px.line(cardano_df, x='date', y='market_caps_diff', title='comparacion del la capitalizacion de mercado en el tiempo de acuredo al dia anterior')
fig_price_returns.show()

# %%
fig = px.line(cardano_df, x="date", y="total_volumes", color="id",
              title="Volumen de la moneda")

fig.show()

# %%
fig_price_returns = px.line(cardano_df, x='date', y='total_volumes_diff', title='comparacion de volumen en el tiempo de acuredo al dia anterior')
fig_price_returns.show()

# %%
# Crear un gráfico de barras de las diferencias de precios en diferentes fechas
fig_price_returns = px.scatter(cardano_df, x='prices', y='returns', title='Relación entre Precios y Retornos de la moneda')
fig_price_returns.show()

# %%
volatility = cardano_df["returns"].std()
print(f"Volatilidad: {volatility:.2%}")
# Out:
# Volatilidad: 0.04%
