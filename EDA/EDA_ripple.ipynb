# %% [markdown]
# # EDA ripple

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
ripple_df = pd.read_csv("../Dataframes/ripple_df.csv")
ripple_df["date"] = pd.to_datetime(ripple_df["date"])

# %%
ripple_df.columns
# Out:
# Index(['date', 'id', 'prices', 'price_diff', 'returns', 'market_caps',
#        'market_caps_diff', 'total_volumes', 'total_volumes_diff', 'open',
#        'high', 'low'],
#       dtype='object')

# %%
ripple_df.head()
# Out:
#         date      id  prices  price_diff  returns  market_caps  \
# 0 2013-08-07  ripple    0.00         0.0      0.0   35071445.0
# 1 2013-08-11  ripple    0.00         0.0      0.0   34180440.0
# 2 2013-08-15  ripple    0.00         0.0      0.0   26014497.0
# 3 2013-08-19  ripple    0.01         0.0      0.0   43465591.0
# 4 2013-08-23  ripple    0.01         0.0      0.0   40146428.0
#
#    market_caps_diff  total_volumes  total_volumes_diff  open  high   low
# 0        -1429188.0            0.0                 0.0  0.01  0.01  0.00
# 1          420134.0            0.0                 0.0  0.00  0.00  0.00
# 2        -4052091.0            0.0                 0.0  0.00  0.00  0.00
# 3        -4986875.0            0.0                 0.0  0.00  0.01  0.00
# 4        -6503702.0            0.0                 0.0  0.01  0.01  0.01

# %%
ripple_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 955 entries, 0 to 954
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                955 non-null    datetime64[ns]
#  1   id                  955 non-null    object
#  2   prices              955 non-null    float64
#  3   price_diff          955 non-null    float64
#  4   returns             955 non-null    float64
#  5   market_caps         955 non-null    float64
#  6   market_caps_diff    955 non-null    float64
#  7   total_volumes       955 non-null    float64
#  8   total_volumes_diff  955 non-null    float64
#  9   open                955 non-null    float64
#  10  high                955 non-null    float64
#  11  low                 955 non-null    float64
# dtypes: datetime64[ns](1), float64(10), object(1)
# memory usage: 89.7+ KB

# %%
ripple_df.describe().astype(str)
# Out:
#                                 date               prices  \
# count                            955                955.0
# mean   2018-08-14 15:52:57.801047040   0.3157486910994764
# min              2013-08-07 00:00:00                  0.0
# 25%              2016-02-13 00:00:00                 0.01
# 50%              2018-08-15 00:00:00                 0.25
# 75%              2021-02-13 00:00:00                 0.46
# max              2023-08-19 00:00:00                  3.4
# std                              nan  0.36479904534720253
#
#                   price_diff                 returns         market_caps  \
# count                  955.0                   955.0               955.0
# mean   0.0014554973821989518  1.4554973821989112e-05  14035524395.911247
# min      -0.2000000000000001                  -0.002          24102550.7
# 25%                      0.0                     0.0       252458343.315
# 50%                      0.0                     0.0      10785539565.84
# ...

# %%
fig = px.line(ripple_df, x="date", y="prices", color="id",
              title="Precio de la moneda")

fig.show()

# %%
fig_price_returns = px.line(ripple_df, x='date', y='price_diff', title='comparacion de precio en el tiempo de acuredo al dia anterior')
fig_price_returns.show()

# %% [markdown]
# Este comportamiento nos muestra que tanto cambia el precio de la moneda

# %%
fig = px.line(ripple_df, x="date", y="market_caps", color="id",
              title="Capitalizacion del mercado de la moneda")

fig.show()

# %% [markdown]
# se puede obserbar que las lineas son muy similares solo que el precio esta en miles y la capitalizacion del mercado esta en miles de millones

# %%
fig_price_returns = px.line(ripple_df, x='date', y='market_caps_diff', title='comparacion del la capitalizacion de mercado en el tiempo de acuredo al dia anterior')
fig_price_returns.show()

# %%
fig = px.line(ripple_df, x="date", y="total_volumes", color="id",
              title="Volumen de la moneda")

fig.show()

# %%
fig_price_returns = px.line(ripple_df, x='date', y='total_volumes_diff', title='comparacion de volumen en el tiempo de acuredo al dia anterior')
fig_price_returns.show()

# %%
# Crear un gráfico de barras de las diferencias de precios en diferentes fechas
fig_price_returns = px.scatter(ripple_df, x='prices', y='returns', title='Relación entre Precios y Retornos de la moneda')
fig_price_returns.show()

# %%
volatility = ripple_df["returns"].std()
print(f"Volatilidad: {volatility:.2%}")
# Out:
# Volatilidad: 0.04%
