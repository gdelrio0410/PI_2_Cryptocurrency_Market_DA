# %% [markdown]
# # Informacion de las monedas seleccionadas

# %%
from pycoingecko import CoinGeckoAPI
from datetime import datetime
import matplotlib.pyplot as plt
import time
import pandas as pd
import myFunctions

# %%
cg = CoinGeckoAPI()

# %%
start_time = myFunctions.unix_time(2000, 1, 1, 0, 0)
end_time = myFunctions.unix_time(2023, 8, 22, 0, 0)

# %% [markdown]
# # bitcoin

# %%
bitcoin_ohlc = myFunctions.coin_ohlc("bitcoin")

bitcoin_coin_market_data = myFunctions.coin_market_chart_data("bitcoin", start_time, end_time)
bitcoin_market_data_df = myFunctions.get_coin_market_dataframe(bitcoin_coin_market_data)
bitcoin_market_data_df['id'] = 'bitcoin'

# Convertir la columna 'prices' a tipo float
bitcoin_market_data_df['prices'] = bitcoin_market_data_df['prices'].astype(float)
bitcoin_market_data_df['market_caps'] = bitcoin_market_data_df['market_caps'].astype(float)
bitcoin_market_data_df['total_volumes'] = bitcoin_market_data_df['total_volumes'].astype(float)

# Calcular la diferencia de prices, market_cap y total_volumes entre el día actual y el día anterior
bitcoin_market_data_df['price_diff'] = bitcoin_market_data_df['prices'] - bitcoin_market_data_df['prices'].shift(1)
bitcoin_market_data_df['market_caps_diff'] = bitcoin_market_data_df['market_caps'] - bitcoin_market_data_df['market_caps'].shift(1)
bitcoin_market_data_df['total_volumes_diff'] = bitcoin_market_data_df['total_volumes'] - bitcoin_market_data_df['total_volumes'].shift(1)

bitcoin_market_data_df

# Convertir las columnas de fecha a tipo datetime
bitcoin_market_data_df['timestamp'] = pd.to_datetime(bitcoin_market_data_df['timestamp'])
bitcoin_ohlc['date'] = pd.to_datetime(bitcoin_ohlc['date'])

# Unir los DataFrames utilizando merge
bitcoin_df = pd.merge(bitcoin_market_data_df, bitcoin_ohlc, left_on='timestamp', right_on='date', how='inner')

columns_to_drop = ['timestamp', "close"]
bitcoin_df.drop(columns=columns_to_drop, inplace=True)

# Reorganizar columnas
new_order = ['date', 'id', 'prices', 'price_diff', 'market_caps', 'market_caps_diff', 'total_volumes', 'total_volumes_diff', 'date', 'open', 'high', 'low']
bitcoin_df = bitcoin_df[new_order]

# Exportar DataFrame a un archivo CSV
bitcoin_df.to_csv('../Dataframes/bitcoin_df.csv', index=False)

bitcoin_df
# Out:
#           date       id    prices  price_diff   market_caps  market_caps_diff  \
# 0   2013-04-30  bitcoin    135.30       -6.66  1.501657e+09     -7.337451e+07
# 1   2013-05-03  bitcoin     91.01      -12.42  1.011066e+09     -1.376012e+08
# 2   2013-05-07  bitcoin    106.40      -11.93  1.183766e+09     -1.322258e+08
# 3   2013-05-11  bitcoin    113.01       -5.77  1.259239e+09     -6.375010e+07
# 4   2013-05-15  bitcoin    114.16       -0.34  1.273850e+09     -3.429307e+06
# ..         ...      ...       ...         ...           ...               ...
# 977 2023-08-03  bitcoin  29146.64     -390.47  5.670747e+11     -5.334220e+09
# 978 2023-08-07  bitcoin  29044.20       -2.60  5.649479e+11     -2.219937e+07
# 979 2023-08-11  bitcoin  29423.82     -161.67  5.724142e+11     -3.121209e+09
# 980 2023-08-15  bitcoin  29400.59      115.62  5.722427e+11      2.555605e+09
# 981 2023-08-19  bitcoin  26042.84     -458.75  5.068158e+11     -9.211102e+09
#
#      total_volumes  total_volumes_diff       date      open      high  \
# 0     0.000000e+00        0.000000e+00 2013-04-30    135.30    141.96
# 1     0.000000e+00        0.000000e+00 2013-05-03    117.00    117.00
# 2     0.000000e+00        0.000000e+00 2013-05-07    111.25    118.33
# 3     0.000000e+00        0.000000e+00 2013-05-11    112.64    118.78
# 4     0.000000e+00        0.000000e+00 2013-05-15    114.71    117.18
# ..             ...                 ...        ...       ...       ...
# 977   1.926632e+10        3.976396e+09 2023-08-03  29233.14  29537.11
# 978   5.360284e+09        2.497485e+07 2023-08-07  29176.15  29176.15
# 979   8.106254e+09       -6.527057e+09 2023-08-11  29178.15  29779.56
# 980   1.240836e+10        7.653135e+09 2023-08-15  29396.85  29412.14
# 981   1.806235e+10       -1.190323e+10 2023-08-19  29170.49  29170.49
#
#           low
# 0      135.30
# 1       91.01
# 2      106.40
# 3      112.64
# 4      114.16
# ..        ...
# 977  29146.64
# 978  29044.20
# 979  29178.15
# 980  29284.97
# 981  26042.84
#
# [982 rows x 12 columns]

# %% [markdown]
# # Ethereum

# %%
ethereum_ohlc = myFunctions.coin_ohlc("ethereum")

ethereum_coin_market_data = myFunctions.coin_market_chart_data("ethereum", start_time, end_time)
ethereum_market_data_df = myFunctions.get_coin_market_dataframe(ethereum_coin_market_data)

ethereum_market_data_df['id'] = 'bitcoin'
# Convertir la columna 'prices' a tipo float
ethereum_market_data_df['prices'] = ethereum_market_data_df['prices'].astype(float)
ethereum_market_data_df['market_caps'] = ethereum_market_data_df['market_caps'].astype(float)
ethereum_market_data_df['total_volumes'] = ethereum_market_data_df['total_volumes'].astype(float)

# Calcular la diferencia de prices, market_cap y total_volumes entre el día actual y el día anterior
ethereum_market_data_df['price_diff'] = ethereum_market_data_df['prices'] - ethereum_market_data_df['prices'].shift(1)
ethereum_market_data_df['market_caps_diff'] = ethereum_market_data_df['market_caps'] - ethereum_market_data_df['market_caps'].shift(1)
ethereum_market_data_df['total_volumes_diff'] = ethereum_market_data_df['total_volumes'] - ethereum_market_data_df['total_volumes'].shift(1)

ethereum_market_data_df

# Convertir las columnas de fecha a tipo datetime
ethereum_market_data_df['timestamp'] = pd.to_datetime(ethereum_market_data_df['timestamp'])
ethereum_ohlc['date'] = pd.to_datetime(ethereum_ohlc['date'])

# Unir los DataFrames utilizando merge
ethereum_df = pd.merge(ethereum_market_data_df, ethereum_ohlc, left_on='timestamp', right_on='date', how='inner')

columns_to_drop = ['timestamp', "close"]
ethereum_df.drop(columns=columns_to_drop, inplace=True)

# Reorganizar columnas
new_order = ['date', 'id', 'prices', 'price_diff', 'market_caps', 'market_caps_diff', 'total_volumes', 'total_volumes_diff', 'date', 'open', 'high', 'low']
ethereum_df = ethereum_df[new_order]

# Exportar DataFrame a un archivo CSV
ethereum_df.to_csv('../Dataframes/ethereum_df.csv', index=False)

ethereum_df
# Out:
#           date       id   prices  price_diff   market_caps  market_caps_diff  \
# 0   2015-08-07  bitcoin     2.83         NaN  0.000000e+00               NaN
# 1   2015-08-11  bitcoin     1.07        0.38  6.453901e+07      2.298270e+07
# 2   2015-08-15  bitcoin     1.67       -0.16  1.012152e+08     -9.340067e+06
# 3   2015-08-19  bitcoin     1.25       -0.03  9.092070e+07     -2.037162e+06
# 4   2015-08-23  bitcoin     1.36       -0.02  9.848800e+07     -1.820762e+06
# ..         ...      ...      ...         ...           ...               ...
# 761 2023-08-03  bitcoin  1838.01      -31.74  2.209365e+11     -5.015559e+09
# 762 2023-08-07  bitcoin  1826.71       -8.36  2.195340e+11     -9.530325e+08
# 763 2023-08-11  bitcoin  1850.88       -5.01  2.224113e+11     -5.811692e+08
# 764 2023-08-15  bitcoin  1843.51        4.00  2.215642e+11      6.159115e+08
# 765 2023-08-19  bitcoin  1660.68      -15.18  1.993229e+11     -2.160098e+09
#
#      total_volumes  total_volumes_diff       date     open     high      low
# 0     9.062200e+04                 NaN 2015-08-07     2.83     2.83     2.83
# 1     1.518998e+06        1.118534e+06 2015-08-11     1.33     1.33     0.69
# 2     2.519633e+06       -1.835985e+06 2015-08-15     1.26     1.83     1.26
# 3     1.537201e+06       -1.588126e+05 2015-08-19     1.48     1.48     1.20
# 4     1.610696e+06        6.961072e+05 2015-08-23     1.48     1.48     1.36
# ..             ...                 ...        ...      ...      ...      ...
# 761   8.178850e+09       -8.119231e+08 2023-08-03  1857.28  1869.75  1838.01
# 762   2.992818e+09        4.046865e+07 2023-08-07  1835.70  1835.70  1826.71
# 763   3.733538e+09       -2.276566e+09 2023-08-11  1826.93  1856.84  1826.93
# 764   4.495325e+09        8.529002e+08 2023-08-15  1847.54  1848.51  1839.51
# 765   1.185691e+10       -9.105864e+09 2023-08-19  1826.91  1826.91  1660.68
#
# [766 rows x 12 columns]

# %% [markdown]
# # Tether

# %%
tether_ohlc = myFunctions.coin_ohlc("tether")

tether_coin_market_data = myFunctions.coin_market_chart_data("tether", start_time, end_time)
tether_market_data_df = myFunctions.get_coin_market_dataframe(tether_coin_market_data)

tether_market_data_df['id'] = 'bitcoin'
# Convertir la columna 'prices' a tipo float
tether_market_data_df['prices'] = tether_market_data_df['prices'].astype(float)
tether_market_data_df['market_caps'] = tether_market_data_df['market_caps'].astype(float)
tether_market_data_df['total_volumes'] = tether_market_data_df['total_volumes'].astype(float)

# Calcular la diferencia de prices, market_cap y total_volumes entre el día actual y el día anterior
tether_market_data_df['price_diff'] = tether_market_data_df['prices'] - tether_market_data_df['prices'].shift(1)
tether_market_data_df['market_caps_diff'] = tether_market_data_df['market_caps'] - tether_market_data_df['market_caps'].shift(1)
tether_market_data_df['total_volumes_diff'] = tether_market_data_df['total_volumes'] - tether_market_data_df['total_volumes'].shift(1)

tether_market_data_df

# Convertir las columnas de fecha a tipo datetime
tether_market_data_df['timestamp'] = pd.to_datetime(tether_market_data_df['timestamp'])
tether_ohlc['date'] = pd.to_datetime(tether_ohlc['date'])

# Unir los DataFrames utilizando merge
tether_df = pd.merge(tether_market_data_df, tether_ohlc, left_on='timestamp', right_on='date', how='inner')

columns_to_drop = ['timestamp', "close"]
tether_df.drop(columns=columns_to_drop, inplace=True)

# Reorganizar columnas
new_order = ['date', 'id', 'prices', 'price_diff', 'market_caps', 'market_caps_diff', 'total_volumes', 'total_volumes_diff', 'date', 'open', 'high', 'low']
tether_df = tether_df[new_order]

# Exportar DataFrame a un archivo CSV
tether_df.to_csv('../Dataframes/tether_df.csv', index=False)

tether_df
# Out:
#           date       id  prices  price_diff   market_caps  market_caps_diff  \
# 0   2015-03-07  bitcoin     1.0         0.0  2.516000e+05      0.000000e+00
# 1   2015-03-11  bitcoin     1.0         0.0  2.516000e+05      0.000000e+00
# 2   2015-03-15  bitcoin     1.0         0.0  2.516000e+05      0.000000e+00
# 3   2015-03-19  bitcoin     1.0         0.0  2.516000e+05      0.000000e+00
# 4   2015-03-23  bitcoin     1.0         0.0  2.516000e+05      0.000000e+00
# ..         ...      ...     ...         ...           ...               ...
# 798 2023-08-03  bitcoin     1.0         0.0  8.388853e+10      7.221443e+07
# 799 2023-08-07  bitcoin     1.0         0.0  8.375169e+10     -6.528705e+07
# 800 2023-08-11  bitcoin     1.0         0.0  8.344563e+10     -5.131214e+07
# 801 2023-08-15  bitcoin     1.0         0.0  8.332348e+10      2.019514e+07
# 802 2023-08-19  bitcoin     1.0         0.0  8.284635e+10      4.415652e+08
#
#      total_volumes  total_volumes_diff       date  open  high  low
# 0     5.819600e+04        5.814600e+04 2015-03-07   1.0   1.0  1.0
# 1     4.600000e+01       -4.996000e+04 2015-03-11   1.0   1.0  1.0
# 2     1.512400e+04       -2.582000e+03 2015-03-15   1.0   1.0  1.0
# 3     8.570000e+02        7.990000e+02 2015-03-19   1.0   1.0  1.0
# 4     6.500000e+01       -1.000000e+00 2015-03-23   1.0   1.0  1.0
# ..             ...                 ...        ...   ...   ...  ...
# 798   2.364385e+10       -1.733185e+09 2023-08-03   1.0   1.0  1.0
# 799   1.134571e+10        2.713086e+09 2023-08-07   1.0   1.0  1.0
# 800   1.089010e+10       -7.877206e+09 2023-08-11   1.0   1.0  1.0
# 801   1.279237e+10        3.538228e+09 2023-08-15   1.0   1.0  1.0
# 802   2.847330e+10       -1.054599e+10 2023-08-19   1.0   1.0  1.0
#
# [803 rows x 12 columns]

# %% [markdown]
# # Binancecoin

# %%
binancecoin_ohlc = myFunctions.coin_ohlc("binancecoin")

binancecoin_coin_market_data = myFunctions.coin_market_chart_data("binancecoin", start_time, end_time)
binancecoin_market_data_df = myFunctions.get_coin_market_dataframe(binancecoin_coin_market_data)

binancecoin_market_data_df['id'] = 'bitcoin'
# Convertir la columna 'prices' a tipo float
binancecoin_market_data_df['prices'] = binancecoin_market_data_df['prices'].astype(float)
binancecoin_market_data_df['market_caps'] = binancecoin_market_data_df['market_caps'].astype(float)
binancecoin_market_data_df['total_volumes'] = binancecoin_market_data_df['total_volumes'].astype(float)

# Calcular la diferencia de prices, market_cap y total_volumes entre el día actual y el día anterior
binancecoin_market_data_df['price_diff'] = binancecoin_market_data_df['prices'] - binancecoin_market_data_df['prices'].shift(1)
binancecoin_market_data_df['market_caps_diff'] = binancecoin_market_data_df['market_caps'] - binancecoin_market_data_df['market_caps'].shift(1)
binancecoin_market_data_df['total_volumes_diff'] = binancecoin_market_data_df['total_volumes'] - binancecoin_market_data_df['total_volumes'].shift(1)

binancecoin_market_data_df

# Convertir las columnas de fecha a tipo datetime
binancecoin_market_data_df['timestamp'] = pd.to_datetime(binancecoin_market_data_df['timestamp'])
binancecoin_ohlc['date'] = pd.to_datetime(binancecoin_ohlc['date'])

# Unir los DataFrames utilizando merge
binancecoin_df = pd.merge(binancecoin_market_data_df, binancecoin_ohlc, left_on='timestamp', right_on='date', how='inner')

columns_to_drop = ['timestamp', "close"]
binancecoin_df.drop(columns=columns_to_drop, inplace=True)

# Reorganizar columnas
new_order = ['date', 'id', 'prices', 'price_diff', 'market_caps', 'market_caps_diff', 'total_volumes', 'total_volumes_diff', 'date', 'open', 'high', 'low']
binancecoin_df = binancecoin_df[new_order]

# Exportar DataFrame a un archivo CSV
binancecoin_df.to_csv('../Dataframes/binancecoin_df.csv', index=False)

binancecoin_df
# Out:
#           date       id  prices  price_diff   market_caps  market_caps_diff  \
# 0   2017-09-19  bitcoin    0.17        0.00  1.683342e+07     -5.157049e+05
# 1   2017-09-23  bitcoin    0.09        0.00  8.828963e+06     -5.923349e+05
# 2   2017-09-27  bitcoin    0.12        0.03  1.150551e+07      2.539733e+06
# 3   2017-09-30  bitcoin    0.17        0.04  1.719116e+07      3.973836e+06
# 4   2017-10-03  bitcoin    0.12        0.01  1.244324e+07      1.655874e+06
# ..         ...      ...     ...         ...           ...               ...
# 559 2023-08-03  bitcoin  240.38       -7.05  3.703518e+10     -9.622428e+08
# 560 2023-08-07  bitcoin  242.57       -0.31  3.732460e+10     -4.325379e+07
# 561 2023-08-11  bitcoin  241.23       -2.78  3.711219e+10     -4.296112e+08
# 562 2023-08-15  bitcoin  240.36        0.33  3.697023e+10      5.641108e+07
# 563 2023-08-19  bitcoin  215.97       -1.83  3.322978e+10     -3.227947e+08
#
#      total_volumes  total_volumes_diff       date    open    high     low
# 0     3.880000e+00       -2.120000e+00 2017-09-19    0.11    0.17    0.11
# 1     7.900000e-01       -1.350900e+02 2017-09-23    0.17    0.17    0.09
# 2     5.955000e+01        4.136000e+01 2017-09-27    0.09    0.12    0.09
# 3     2.046400e+02        2.020200e+02 2017-09-30    0.14    0.17    0.13
# 4     4.209000e+01        2.765000e+01 2017-10-03    0.10    0.12    0.10
# ..             ...                 ...        ...     ...     ...     ...
# 559   7.502332e+08       -1.041493e+08 2023-08-03  241.19  247.43  240.38
# 560   3.723593e+08        1.208226e+08 2023-08-07  241.14  242.88  241.14
# 561   3.390474e+08       -6.245683e+07 2023-08-11  241.74  245.18  241.23
# 562   3.232128e+08        9.244901e+07 2023-08-15  239.60  240.36  239.60
# 563   6.146381e+08       -3.316293e+08 2023-08-19  236.61  236.61  215.97
#
# [564 rows x 12 columns]

# %% [markdown]
# # Ripple

# %%
ripple_ohlc = myFunctions.coin_ohlc("ripple")

ripple_coin_market_data = myFunctions.coin_market_chart_data("ripple", start_time, end_time)
ripple_market_data_df = myFunctions.get_coin_market_dataframe(ripple_coin_market_data)

ripple_market_data_df['id'] = 'bitcoin'
# Convertir la columna 'prices' a tipo float
ripple_market_data_df['prices'] = ripple_market_data_df['prices'].astype(float)
ripple_market_data_df['market_caps'] = ripple_market_data_df['market_caps'].astype(float)
ripple_market_data_df['total_volumes'] = ripple_market_data_df['total_volumes'].astype(float)

# Calcular la diferencia de prices, market_cap y total_volumes entre el día actual y el día anterior
ripple_market_data_df['price_diff'] = ripple_market_data_df['prices'] - ripple_market_data_df['prices'].shift(1)
ripple_market_data_df['market_caps_diff'] = ripple_market_data_df['market_caps'] - ripple_market_data_df['market_caps'].shift(1)
ripple_market_data_df['total_volumes_diff'] = ripple_market_data_df['total_volumes'] - ripple_market_data_df['total_volumes'].shift(1)

ripple_market_data_df

# Convertir las columnas de fecha a tipo datetime
ripple_market_data_df['timestamp'] = pd.to_datetime(ripple_market_data_df['timestamp'])
ripple_ohlc['date'] = pd.to_datetime(ripple_ohlc['date'])

# Unir los DataFrames utilizando merge
ripple_df = pd.merge(ripple_market_data_df, ripple_ohlc, left_on='timestamp', right_on='date', how='inner')

columns_to_drop = ['timestamp', "close"]
ripple_df.drop(columns=columns_to_drop, inplace=True)

# Reorganizar columnas
new_order = ['date', 'id', 'prices', 'price_diff', 'market_caps', 'market_caps_diff', 'total_volumes', 'total_volumes_diff', 'date', 'open', 'high', 'low']
ripple_df = ripple_df[new_order]

# Exportar DataFrame a un archivo CSV
ripple_df.to_csv('../Dataframes/ripple_df.csv', index=False)

ripple_df
# Out:
#           date       id  prices  price_diff   market_caps  market_caps_diff  \
# 0   2013-08-07  bitcoin    0.00        0.00  3.507144e+07     -1.429188e+06
# 1   2013-08-11  bitcoin    0.00        0.00  3.418044e+07      4.201340e+05
# 2   2013-08-15  bitcoin    0.00        0.00  2.601450e+07     -4.052091e+06
# 3   2013-08-19  bitcoin    0.01        0.00  4.346559e+07     -4.986875e+06
# 4   2013-08-23  bitcoin    0.01        0.00  4.014643e+07     -6.503702e+06
# ..         ...      ...     ...         ...           ...               ...
# 950 2023-08-03  bitcoin    0.68       -0.03  3.612055e+10     -1.057130e+09
# 951 2023-08-07  bitcoin    0.62       -0.01  3.276840e+10     -3.584649e+08
# 952 2023-08-11  bitcoin    0.63       -0.01  3.342676e+10     -5.506590e+08
# 953 2023-08-15  bitcoin    0.63        0.00  3.352678e+10      5.058452e+08
# 954 2023-08-19  bitcoin    0.51        0.01  2.667860e+10      1.238305e+07
#
#      total_volumes  total_volumes_diff       date  open  high   low
# 0     0.000000e+00        0.000000e+00 2013-08-07  0.01  0.01  0.00
# 1     0.000000e+00        0.000000e+00 2013-08-11  0.00  0.00  0.00
# 2     0.000000e+00        0.000000e+00 2013-08-15  0.00  0.00  0.00
# 3     0.000000e+00        0.000000e+00 2013-08-19  0.00  0.01  0.00
# 4     0.000000e+00        0.000000e+00 2013-08-23  0.01  0.01  0.01
# ..             ...                 ...        ...   ...   ...   ...
# 950   1.053596e+09       -4.676914e+08 2023-08-03  0.70  0.71  0.68
# 951   7.710698e+08       -2.311294e+08 2023-08-07  0.66  0.66  0.62
# 952   1.063358e+09       -4.350368e+08 2023-08-11  0.62  0.64  0.62
# 953   9.673053e+08        3.463654e+08 2023-08-15  0.63  0.63  0.63
# 954   1.918959e+09       -2.761486e+08 2023-08-19  0.61  0.61  0.50
#
# [955 rows x 12 columns]

# %% [markdown]
# # usd-coin

# %%
usd_coin_ohlc = myFunctions.coin_ohlc("usd-coin")

usd_coin_coin_market_data = myFunctions.coin_market_chart_data("usd-coin", start_time, end_time)
usd_coin_market_data_df = myFunctions.get_coin_market_dataframe(usd_coin_coin_market_data)

usd_coin_market_data_df['id'] = 'bitcoin'
# Convertir la columna 'prices' a tipo float
usd_coin_market_data_df['prices'] = usd_coin_market_data_df['prices'].astype(float)
usd_coin_market_data_df['market_caps'] = usd_coin_market_data_df['market_caps'].astype(float)
usd_coin_market_data_df['total_volumes'] = usd_coin_market_data_df['total_volumes'].astype(float)

# Calcular la diferencia de prices, market_cap y total_volumes entre el día actual y el día anterior
usd_coin_market_data_df['price_diff'] = usd_coin_market_data_df['prices'] - usd_coin_market_data_df['prices'].shift(1)
usd_coin_market_data_df['market_caps_diff'] = usd_coin_market_data_df['market_caps'] - usd_coin_market_data_df['market_caps'].shift(1)
usd_coin_market_data_df['total_volumes_diff'] = usd_coin_market_data_df['total_volumes'] - usd_coin_market_data_df['total_volumes'].shift(1)

usd_coin_market_data_df

# Convertir las columnas de fecha a tipo datetime
usd_coin_market_data_df['timestamp'] = pd.to_datetime(usd_coin_market_data_df['timestamp'])
usd_coin_ohlc['date'] = pd.to_datetime(usd_coin_ohlc['date'])

# Unir los DataFrames utilizando merge
usd_coin_df = pd.merge(usd_coin_market_data_df, usd_coin_ohlc, left_on='timestamp', right_on='date', how='inner')

columns_to_drop = ['timestamp', "close"]
usd_coin_df.drop(columns=columns_to_drop, inplace=True)

# Reorganizar columnas
new_order = ['date', 'id', 'prices', 'price_diff', 'market_caps', 'market_caps_diff', 'total_volumes', 'total_volumes_diff', 'date', 'open', 'high', 'low']
usd_coin_df = usd_coin_df[new_order]

# Exportar DataFrame a un archivo CSV
usd_coin_df.to_csv('../Dataframes/usd_coin_df.csv', index=False)

usd_coin_df
# Out:
#           date       id  prices  price_diff   market_caps  market_caps_diff  \
# 0   2018-10-07  bitcoin    1.00        0.00  0.000000e+00      0.000000e+00
# 1   2018-10-11  bitcoin    1.00        0.00  0.000000e+00      0.000000e+00
# 2   2018-10-15  bitcoin    1.02        0.01  0.000000e+00      0.000000e+00
# 3   2018-10-19  bitcoin    1.02       -0.01  0.000000e+00     -2.459024e+07
# 4   2018-10-23  bitcoin    1.02       -0.01  0.000000e+00      0.000000e+00
# ..         ...      ...     ...         ...           ...               ...
# 459 2023-08-03  bitcoin    1.00        0.00  2.619386e+10     -1.264121e+08
# 460 2023-08-07  bitcoin    1.00        0.00  2.604314e+10      2.781969e+06
# 461 2023-08-11  bitcoin    1.00        0.00  2.615260e+10     -1.316599e+08
# 462 2023-08-15  bitcoin    1.00        0.00  2.600436e+10     -1.762234e+08
# 463 2023-08-19  bitcoin    1.00        0.00  2.599099e+10     -2.072892e+07
#
#      total_volumes  total_volumes_diff       date  open  high   low
# 0     4.932469e+04        2.906998e+04 2018-10-07  1.01  1.01  1.00
# 1     4.878948e+04        6.976980e+03 2018-10-11  1.00  1.00  1.00
# 2     1.140475e+05       -1.975891e+04 2018-10-15  1.01  1.02  1.01
# 3     5.770299e+05       -1.242982e+06 2018-10-19  1.04  1.04  1.02
# 4     4.756981e+05        2.644474e+05 2018-10-23  1.02  1.03  1.02
# ..             ...                 ...        ...   ...   ...   ...
# 459   4.492430e+09       -8.336773e+08 2023-08-03  1.00  1.00  1.00
# 460   1.874549e+09        1.988404e+08 2023-08-07  1.00  1.00  1.00
# 461   2.203564e+09       -8.133757e+08 2023-08-11  1.00  1.00  1.00
# 462   2.461886e+09        7.800588e+08 2023-08-15  1.00  1.00  1.00
# 463   4.443167e+09        2.689318e+07 2023-08-19  1.00  1.00  1.00
#
# [464 rows x 12 columns]

# %% [markdown]
# # staked-ether

# %%
staked_ether_ohlc = myFunctions.coin_ohlc("staked-ether")

staked_ether_coin_market_data = myFunctions.coin_market_chart_data("staked-ether", start_time, end_time)
staked_ether_market_data_df = myFunctions.get_coin_market_dataframe(staked_ether_coin_market_data)

staked_ether_market_data_df['id'] = 'bitcoin'
# Convertir la columna 'prices' a tipo float
staked_ether_market_data_df['prices'] = staked_ether_market_data_df['prices'].astype(float)
staked_ether_market_data_df['market_caps'] = staked_ether_market_data_df['market_caps'].astype(float)
staked_ether_market_data_df['total_volumes'] = staked_ether_market_data_df['total_volumes'].astype(float)

# Calcular la diferencia de prices, market_cap y total_volumes entre el día actual y el día anterior
staked_ether_market_data_df['price_diff'] = staked_ether_market_data_df['prices'] - staked_ether_market_data_df['prices'].shift(1)
staked_ether_market_data_df['market_caps_diff'] = staked_ether_market_data_df['market_caps'] - staked_ether_market_data_df['market_caps'].shift(1)
staked_ether_market_data_df['total_volumes_diff'] = staked_ether_market_data_df['total_volumes'] - staked_ether_market_data_df['total_volumes'].shift(1)

staked_ether_market_data_df

# Convertir las columnas de fecha a tipo datetime
staked_ether_market_data_df['timestamp'] = pd.to_datetime(staked_ether_market_data_df['timestamp'])
staked_ether_ohlc['date'] = pd.to_datetime(staked_ether_ohlc['date'])

# Unir los DataFrames utilizando merge
staked_ether_df = pd.merge(staked_ether_market_data_df, staked_ether_ohlc, left_on='timestamp', right_on='date', how='inner')

columns_to_drop = ['timestamp', "close"]
staked_ether_df.drop(columns=columns_to_drop, inplace=True)

# Reorganizar columnas
new_order = ['date', 'id', 'prices', 'price_diff', 'market_caps', 'market_caps_diff', 'total_volumes', 'total_volumes_diff', 'date', 'open', 'high', 'low']
staked_ether_df = staked_ether_df[new_order]

# Exportar DataFrame a un archivo CSV
staked_ether_df.to_csv('../Dataframes/staked_ether_df.csv', index=False)

staked_ether_df
# Out:
#           date       id   prices  price_diff   market_caps  market_caps_diff  \
# 0   2020-12-23  bitcoin   617.16        0.00  0.000000e+00      0.000000e+00
# 1   2020-12-27  bitcoin   629.07        4.27  7.530256e+06      2.455121e+05
# 2   2020-12-31  bitcoin   722.28       -0.49  1.190541e+07      4.120375e+05
# 3   2021-01-03  bitcoin   772.06       48.53  1.320595e+07      1.082508e+06
# 4   2021-01-07  bitcoin  1173.33       59.43  2.139665e+07      2.014801e+06
# ..         ...      ...      ...         ...           ...               ...
# 248 2023-08-03  bitcoin  1836.06      -43.16  1.462211e+10     -2.229318e+08
# 249 2023-08-07  bitcoin  1826.24       -8.86  1.458317e+10     -5.758513e+07
# 250 2023-08-11  bitcoin  1849.45       -5.91  1.489187e+10      8.837115e+06
# 251 2023-08-15  bitcoin  1842.55        4.64  1.493220e+10      5.506370e+07
# 252 2023-08-19  bitcoin  1659.99      -18.54  1.356056e+10     -1.397835e+08
#
#      total_volumes  total_volumes_diff       date     open     high      low
# 0        137563.03                0.00 2020-12-23   617.16   617.16   617.16
# 1         10300.37           -35632.69 2020-12-27   596.77   629.07   596.77
# 2         95848.21           -20893.23 2020-12-31   678.10   730.42   678.10
# 3         34572.92            29468.27 2021-01-03   733.32   772.06   723.53
# 4         38065.92          -404512.05 2021-01-07   977.57  1173.33   966.90
# ..             ...                 ...        ...      ...      ...      ...
# 248    43552961.49        -28931698.29 2023-08-03  1857.55  1879.22  1836.06
# 249    26173043.14         19801449.17 2023-08-07  1835.27  1835.27  1826.24
# 250    22500456.48        -10745133.37 2023-08-11  1821.72  1856.80  1821.72
# 251     5027849.07          1411037.18 2023-08-15  1846.30  1846.71  1837.91
# 252    25265068.44         -2288588.90 2023-08-19  1826.36  1826.36  1659.99
#
# [253 rows x 12 columns]

# %% [markdown]
# # cardano

# %%
cardano_ohlc = myFunctions.coin_ohlc("cardano")

cardano_coin_market_data = myFunctions.coin_market_chart_data("cardano", start_time, end_time)
cardano_market_data_df = myFunctions.get_coin_market_dataframe(cardano_coin_market_data)

cardano_market_data_df['id'] = 'bitcoin'
# Convertir la columna 'prices' a tipo float
cardano_market_data_df['prices'] = cardano_market_data_df['prices'].astype(float)
cardano_market_data_df['market_caps'] = cardano_market_data_df['market_caps'].astype(float)
cardano_market_data_df['total_volumes'] = cardano_market_data_df['total_volumes'].astype(float)

# Calcular la diferencia de prices, market_cap y total_volumes entre el día actual y el día anterior
cardano_market_data_df['price_diff'] = cardano_market_data_df['prices'] - cardano_market_data_df['prices'].shift(1)
cardano_market_data_df['market_caps_diff'] = cardano_market_data_df['market_caps'] - cardano_market_data_df['market_caps'].shift(1)
cardano_market_data_df['total_volumes_diff'] = cardano_market_data_df['total_volumes'] - cardano_market_data_df['total_volumes'].shift(1)

cardano_market_data_df

# Convertir las columnas de fecha a tipo datetime
cardano_market_data_df['timestamp'] = pd.to_datetime(cardano_market_data_df['timestamp'])
cardano_ohlc['date'] = pd.to_datetime(cardano_ohlc['date'])

# Unir los DataFrames utilizando merge
cardano_df = pd.merge(cardano_market_data_df, cardano_ohlc, left_on='timestamp', right_on='date', how='inner')

columns_to_drop = ['timestamp', "close"]
cardano_df.drop(columns=columns_to_drop, inplace=True)

# Reorganizar columnas
new_order = ['date', 'id', 'prices', 'price_diff', 'market_caps', 'market_caps_diff', 'total_volumes', 'total_volumes_diff', 'date', 'open', 'high', 'low']
cardano_df = cardano_df[new_order]

# Exportar DataFrame a un archivo CSV
cardano_df.to_csv('../Dataframes/cardano_df.csv', index=False)

cardano_df
# Out:
#           date       id  prices  price_diff   market_caps  market_caps_diff  \
# 0   2017-10-19  bitcoin    0.03        0.00  6.956220e+08     -3.993860e+05
# 1   2017-10-23  bitcoin    0.03        0.00  6.752738e+08     -4.539603e+07
# 2   2017-10-27  bitcoin    0.03        0.00  6.873168e+08     -2.120287e+06
# 3   2017-10-31  bitcoin    0.03        0.00  7.843223e+08      4.837182e+07
# 4   2017-11-03  bitcoin    0.02        0.00  5.908631e+08      3.808294e+07
# ..         ...      ...     ...         ...           ...               ...
# 551 2023-08-03  bitcoin    0.30       -0.01  1.048192e+10     -3.436780e+08
# 552 2023-08-07  bitcoin    0.29        0.00  1.021785e+10     -6.297062e+07
# 553 2023-08-11  bitcoin    0.30        0.00  1.037526e+10     -1.874160e+08
# 554 2023-08-15  bitcoin    0.29        0.00  1.018196e+10      4.691557e+07
# 555 2023-08-19  bitcoin    0.26        0.01  9.235486e+09      3.169831e+08
#
#      total_volumes  total_volumes_diff       date  open  high   low
# 0     2.815156e+06           463477.85 2017-10-19  0.03  0.03  0.03
# 1     3.505127e+06           603250.42 2017-10-23  0.03  0.03  0.03
# 2     2.569634e+06           200233.54 2017-10-27  0.03  0.03  0.03
# 3     7.251417e+06          3456663.93 2017-10-31  0.03  0.03  0.03
# 4     3.029090e+06         -2926161.61 2017-11-03  0.02  0.02  0.02
# ..             ...                 ...        ...   ...   ...   ...
# 551   2.082139e+08        -34328266.25 2023-08-03  0.31  0.31  0.30
# 552   1.507591e+08         -6770456.48 2023-08-07  0.29  0.29  0.29
# 553   1.794778e+08        -16040871.41 2023-08-11  0.29  0.30  0.29
# 554   1.298745e+08          4768173.24 2023-08-15  0.29  0.29  0.29
# 555   2.651095e+08        -75534069.98 2023-08-19  0.28  0.28  0.25
#
# [556 rows x 12 columns]

# %% [markdown]
# # dogecoin

# %%
dogecoin_ohlc = myFunctions.coin_ohlc("dogecoin")

dogecoin_coin_market_data = myFunctions.coin_market_chart_data("dogecoin", start_time, end_time)
dogecoin_market_data_df = myFunctions.get_coin_market_dataframe(dogecoin_coin_market_data)

dogecoin_market_data_df['id'] = 'bitcoin'
# Convertir la columna 'prices' a tipo float
dogecoin_market_data_df['prices'] = dogecoin_market_data_df['prices'].astype(float)
dogecoin_market_data_df['market_caps'] = dogecoin_market_data_df['market_caps'].astype(float)
dogecoin_market_data_df['total_volumes'] = dogecoin_market_data_df['total_volumes'].astype(float)

# Calcular la diferencia de prices, market_cap y total_volumes entre el día actual y el día anterior
dogecoin_market_data_df['price_diff'] = dogecoin_market_data_df['prices'] - dogecoin_market_data_df['prices'].shift(1)
dogecoin_market_data_df['market_caps_diff'] = dogecoin_market_data_df['market_caps'] - dogecoin_market_data_df['market_caps'].shift(1)
dogecoin_market_data_df['total_volumes_diff'] = dogecoin_market_data_df['total_volumes'] - dogecoin_market_data_df['total_volumes'].shift(1)

dogecoin_market_data_df

# Convertir las columnas de fecha a tipo datetime
dogecoin_market_data_df['timestamp'] = pd.to_datetime(dogecoin_market_data_df['timestamp'])
dogecoin_ohlc['date'] = pd.to_datetime(dogecoin_ohlc['date'])

# Unir los DataFrames utilizando merge
dogecoin_df = pd.merge(dogecoin_market_data_df, dogecoin_ohlc, left_on='timestamp', right_on='date', how='inner')

columns_to_drop = ['timestamp', "close"]
dogecoin_df.drop(columns=columns_to_drop, inplace=True)

# Reorganizar columnas
new_order = ['date', 'id', 'prices', 'price_diff', 'market_caps', 'market_caps_diff', 'total_volumes', 'total_volumes_diff', 'date', 'open', 'high', 'low']
dogecoin_df = dogecoin_df[new_order]

# Exportar DataFrame a un archivo CSV
dogecoin_df.to_csv('../Dataframes/dogecoin_df.csv', index=False)

dogecoin_df
# Out:
#           date       id  prices  price_diff   market_caps  market_caps_diff  \
# 0   2013-12-15  bitcoin    0.00         NaN  3.488670e+06               NaN
# 1   2013-12-19  bitcoin    0.00        0.00  4.299422e+06      2.107435e+06
# 2   2013-12-23  bitcoin    0.00        0.00  4.022744e+06     -6.168220e+05
# 3   2013-12-27  bitcoin    0.00        0.00  8.200082e+06      1.853080e+05
# 4   2013-12-31  bitcoin    0.00        0.00  7.902574e+06      3.273450e+05
# ..         ...      ...     ...         ...           ...               ...
# 917 2023-08-03  bitcoin    0.07       -0.01  1.041960e+10     -5.059634e+08
# 918 2023-08-07  bitcoin    0.07       -0.01  1.041788e+10     -1.976403e+08
# 919 2023-08-11  bitcoin    0.08        0.00  1.064195e+10      4.517115e+07
# 920 2023-08-15  bitcoin    0.07        0.00  1.051512e+10      1.116186e+07
# 921 2023-08-19  bitcoin    0.06        0.00  8.883843e+09      2.931383e+08
#
#      total_volumes  total_volumes_diff       date  open  high   low
# 0     0.000000e+00                 NaN 2013-12-15  0.00  0.00  0.00
# 1     0.000000e+00        0.000000e+00 2013-12-19  0.00  0.00  0.00
# 2     0.000000e+00        0.000000e+00 2013-12-23  0.00  0.00  0.00
# 3     4.086430e+05        4.086430e+05 2013-12-27  0.00  0.00  0.00
# 4     3.079710e+05       -1.905100e+04 2013-12-31  0.00  0.00  0.00
# ..             ...                 ...        ...   ...   ...   ...
# 917   4.378788e+08       -1.350934e+07 2023-08-03  0.08  0.08  0.07
# 918   3.690576e+08       -1.699763e+08 2023-08-07  0.07  0.08  0.07
# 919   3.993660e+08        2.961785e+07 2023-08-11  0.07  0.08  0.07
# 920   4.339586e+08        1.084278e+08 2023-08-15  0.08  0.08  0.07
# 921   5.861529e+08       -2.892601e+08 2023-08-19  0.07  0.07  0.06
#
# [922 rows x 12 columns]

# %% [markdown]
# # solana

# %%
solana_ohlc = myFunctions.coin_ohlc("solana")

solana_coin_market_data = myFunctions.coin_market_chart_data("solana", start_time, end_time)
solana_market_data_df = myFunctions.get_coin_market_dataframe(solana_coin_market_data)

solana_market_data_df['id'] = 'bitcoin'
# Convertir la columna 'prices' a tipo float
solana_market_data_df['prices'] = solana_market_data_df['prices'].astype(float)
solana_market_data_df['market_caps'] = solana_market_data_df['market_caps'].astype(float)
solana_market_data_df['total_volumes'] = solana_market_data_df['total_volumes'].astype(float)

# Calcular la diferencia de prices, market_cap y total_volumes entre el día actual y el día anterior
solana_market_data_df['price_diff'] = solana_market_data_df['prices'] - solana_market_data_df['prices'].shift(1)
solana_market_data_df['market_caps_diff'] = solana_market_data_df['market_caps'] - solana_market_data_df['market_caps'].shift(1)
solana_market_data_df['total_volumes_diff'] = solana_market_data_df['total_volumes'] - solana_market_data_df['total_volumes'].shift(1)

solana_market_data_df

# Convertir las columnas de fecha a tipo datetime
solana_market_data_df['timestamp'] = pd.to_datetime(solana_market_data_df['timestamp'])
solana_ohlc['date'] = pd.to_datetime(solana_ohlc['date'])

# Unir los DataFrames utilizando merge
solana_df = pd.merge(solana_market_data_df, solana_ohlc, left_on='timestamp', right_on='date', how='inner')

columns_to_drop = ['timestamp', "close"]
solana_df.drop(columns=columns_to_drop, inplace=True)

# Reorganizar columnas
new_order = ['date', 'id', 'prices', 'price_diff', 'market_caps', 'market_caps_diff', 'total_volumes', 'total_volumes_diff', 'date', 'open', 'high', 'low']
solana_df = solana_df[new_order]

# Exportar DataFrame a un archivo CSV
solana_df.to_csv('../Dataframes/solana_df.csv', index=False)

solana_df
# Out:
#           date       id  prices  price_diff   market_caps  market_caps_diff  \
# 0   2020-04-11  bitcoin    0.96         NaN  7.827652e+06               NaN
# 1   2020-04-15  bitcoin    0.67       -0.12  5.306221e+06     -9.961431e+05
# 2   2020-04-19  bitcoin    0.68        0.02  5.423066e+06      7.474231e+04
# 3   2020-04-23  bitcoin    0.68        0.11  5.446538e+06      8.549914e+05
# 4   2020-04-27  bitcoin    0.64       -0.01  5.137791e+06     -3.582790e+04
# ..         ...      ...     ...         ...           ...               ...
# 315 2023-08-03  bitcoin   23.13       -0.80  9.376126e+09     -2.875034e+08
# 316 2023-08-07  bitcoin   23.16        0.53  9.384286e+09      2.287942e+08
# 317 2023-08-11  bitcoin   24.62        0.24  9.982519e+09      8.782001e+07
# 318 2023-08-15  bitcoin   25.15        0.93  1.021132e+10      3.717702e+08
# 319 2023-08-19  bitcoin   21.33       -0.32  8.681696e+09     -1.516802e+08
#
#      total_volumes  total_volumes_diff       date   open   high    low
# 0     9.267267e+07                 NaN 2020-04-11   0.96   0.96   0.96
# 1     1.752353e+07       -2.055682e+06 2020-04-15   0.78   0.88   0.67
# 2     1.019932e+07       -2.771659e+04 2020-04-19   0.64   0.69   0.64
# 3     1.814679e+07        8.535948e+06 2020-04-23   0.61   0.68   0.53
# 4     8.493459e+06        1.168498e+06 2020-04-27   0.62   0.65   0.62
# ..             ...                 ...        ...    ...    ...    ...
# 315   4.269454e+08       -6.984695e+06 2023-08-03  23.76  23.93  23.13
# 316   3.381710e+08        8.180034e+07 2023-08-07  22.65  23.16  22.63
# 317   3.521246e+08       -1.059151e+08 2023-08-11  23.05  24.62  23.05
# 318   3.880259e+08        1.098438e+08 2023-08-15  24.58  25.15  24.22
# 319   4.122202e+08       -2.441924e+08 2023-08-19  23.88  23.88  21.33
#
# [320 rows x 12 columns]

# %% [markdown]
# ------------
